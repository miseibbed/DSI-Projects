# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Los Angeles Unified School District recently signed a contract with an external organization providing coaching to improve student college and career readiness for a select group of schools with a focus on reading/writing and math content areas. As a contractor, I am tasked with analyzing standardized test performance data for 12th graders from previous school years (2019) to identify trends to assist LAUSD and the external organization in narrowing down their focus. Should coaches focus on one or both content areas and should school socioeconomic status be a factor in school selection?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
# - **[`act_2019_ca.csv`](./data/act_2019_ca.csv)**: This dataset was sourced from the California Department of Education website. It includes 2018-2019 academic year 12th grade ACT performance broken down by average reading, english, math, and science scores. It also includes the percentage of testtakers that met the ACT benchmark. Data is available at the school, district, county, and state level.
# - **[`sat_2019_ca.csv`](./data/frpm1819.csv)**: This dataset was sourced from the California Department of Education website. It includes 2018-2019 academic year 11th and 12th grade SAT performance broken down by number of stuents meeting the english/writing, math, and composite SAT benchmarks. Data is available at the school, district, county, and state level.
# - **[`frpm1819.csv`](./data/sat_2019_ca.csv)**: This dataset was sourced from the California Department of Education website. It includes 2018-2019 percentage of studens eligible for free reduced price meal, school attributes (charter school status, funding type, school type, etc.) Data is available at the school, district, county, and state level.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# - LAUSD 2022-2026 Stategic Plan | https://fairtest.org/test-optional-list/)
# - National Center for Fair & Open Testing: ACT/SAT Optional List | https://fairtest.org/test-optional-list/

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def mean_of_values(numbers):    #def the function and inputs
    for num in numbers:
        return sum(numbers) / len(numbers)

mean_of_values([1,2,3,4,5])
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Xi represents each value in the dataset,  𝜇 represents the mean of all values in the dataset, n represents the number of values in dataset
sample = [1,2,3,4,5]  #create a sample list

def std_deviation(values):
    list = []      # create empty list
    for val in values:
        list.append((val - mean_of_values(values)) ** 2)   # take the squared of the val - mean and add it to the list
        s_dev = (sum(list) / len(values)) ** 0.5           # take sum of items in list and divide it by total in list, then take the square root
    return s_dev
    
std_deviation(sample)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def float_converter(string):
    return float(string.strip('%')) / 100    # remove the %, turn the str into a float, then divide by 100 to get decimal approx of the percent

float_converter('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# imports libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ___

# %% [markdown]
# ### Load the Data ###

# %% [markdown]
# #### *Dataset 1 - ACT 2019 SAT Data* ####

# %%
# import act_2019_ca csv data and assign it to a df called act_2019_ca
act_2019_ca = pd.read_csv('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/data/act_2019_ca.csv')
act_2019_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
act_2019_ca.info()

#2310 rows, 18 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %% [markdown]
# ### Data cleaning applied to ACT dataset
# * dropped unwanted columns
# * filtered dataset for schools within the Lod Angeles Unified district
# * filtered dataset to only include rows at the school aggregate level
# * addressed nulls/missing values and special character '*'
# * renamed column names
# * change data types to its appropriate data type

# %%
# drop unwanted cols
act_2019_ca.drop(columns = 'Unnamed: 17', inplace = True)

# %%
# just checking Dtypes
act_2019_ca['RType'].unique()
# Out:
# array(['S', 'C', 'D', 'X', nan], dtype=object)

# %%
#filter for only Los Angeles Unified data and create a new df
# DName = Los Angeles Unified
# Rtype

LAUSD_act2019 = act_2019_ca[act_2019_ca['DName'] == 'Los Angeles Unified']
#LAUSD_act2019.head(2)
LAUSD_act2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 4 to 2300
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CDS         200 non-null    float64
#  1   CCode       200 non-null    float64
#  2   CDCode      200 non-null    float64
#  3   SCode       199 non-null    float64
#  4   RType       200 non-null    object
#  5   SName       199 non-null    object
#  6   DName       200 non-null    object
#  7   CName       200 non-null    object
#  8   Enroll12    200 non-null    float64
#  9   NumTstTakr  200 non-null    float64
#  10  AvgScrRead  186 non-null    object
#  11  AvgScrEng   186 non-null    object
#  12  AvgScrMath  186 non-null    object
#  13  AvgScrSci   186 non-null    object
#  14  NumGE21     186 non-null    object
#  15  PctGE21     186 non-null    object
#  16  Year        200 non-null    object
# dtypes: float64(6), object(11)
# memory usage: 28.1+ KB

# %%
# count of missing values
LAUSD_act2019.isna().sum()
# Out:
# CDS            0
# CCode          0
# CDCode         0
# SCode          1
# RType          0
# SName          1
# DName          0
# CName          0
# Enroll12       0
# NumTstTakr     0
# AvgScrRead    14
# AvgScrEng     14
# AvgScrMath    14
# AvgScrSci     14
# NumGE21       14
# PctGE21       14
# Year           0
# dtype: int64

# %%
LAUSD_act2019[LAUSD_act2019['SCode'].isna()]

# we can see that the total district performance was included in the filter
# this info would be helpful, but not in this df - filter out this row of data
# Out:
#                CDS  CCode     CDCode  SCode RType SName                DName  \
# 1282  1.964733e+13   19.0  1964733.0    NaN     D   NaN  Los Angeles Unified
#
#             CName  Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath  \
# 1282  Los Angeles   41873.0      9336.0         19        18         19
#
#      AvgScrSci NumGE21 PctGE21     Year
# 1282        19    2774   29.71  2018-19

# %%
# remove the row of data where SCode is NaN
# LAUSD_act2019[LAUSD_act2019['SCode'].notna()] # I can see that 199 rows were returned which makes sense
LAUSD_act2019 = LAUSD_act2019.loc[LAUSD_act2019['SCode'].notna()]

# %%
# 14 schools have no SAT data reported for 18-19. I think it would make the most sense to drop it
# since 14 rows is about 7% of the data - might be okay to filter these out

# filter out rows of data where Number of test takers = 0
# LAUSD_act2019[LAUSD_act2019['PctGE21'].isna()]   - i used this to explore the data and found that all rows with null vals had 0 Students that took the ACT

LAUSD_act2019 = LAUSD_act2019[LAUSD_act2019['NumTstTakr'] != 0]
LAUSD_act2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185 entries, 4 to 2294
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CDS         185 non-null    float64
#  1   CCode       185 non-null    float64
#  2   CDCode      185 non-null    float64
#  3   SCode       185 non-null    float64
#  4   RType       185 non-null    object
#  5   SName       185 non-null    object
#  6   DName       185 non-null    object
#  7   CName       185 non-null    object
#  8   Enroll12    185 non-null    float64
#  9   NumTstTakr  185 non-null    float64
#  10  AvgScrRead  185 non-null    object
#  11  AvgScrEng   185 non-null    object
#  12  AvgScrMath  185 non-null    object
#  13  AvgScrSci   185 non-null    object
#  14  NumGE21     185 non-null    object
#  15  PctGE21     185 non-null    object
#  16  Year        185 non-null    object
# dtypes: float64(6), object(11)
# memory usage: 26.0+ KB

# %%
# LAUSD_act2019[LAUSD_act2019['AvgScrEng'] == '*']

# wouldn't recommend dropping the rows, but don't include in analysis
# ~25% of data has * in certain cols
# replace * with np.NaN

LAUSD_act2019 = LAUSD_act2019.replace('*', np.NaN)

# %%
LAUSD_act2019[LAUSD_act2019['AvgScrEng'] == '*'] # now we don't have rows with *
# Out:
# Empty DataFrame
# Columns: [CDS, CCode, CDCode, SCode, RType, SName, DName, CName, Enroll12, NumTstTakr, AvgScrRead, AvgScrEng, AvgScrMath, AvgScrSci, NumGE21, PctGE21, Year]
# Index: []

# %%
# return rows where there are NaNs
# there are 51 schools where no scores were reported for the 12th graders on the ACT 51/185 ~28% of the high schools
LAUSD_act2019[LAUSD_act2019.isna().any(axis=1)].count()
# Out:
# CDS           51
# CCode         51
# CDCode        51
# SCode         51
# RType         51
# SName         51
# DName         51
# CName         51
# Enroll12      51
# NumTstTakr    51
# AvgScrRead     0
# AvgScrEng      0
# AvgScrMath     0
# AvgScrSci      0
# NumGE21        0
# PctGE21        0
# Year          51
# dtype: int64

# %%
# drop 51 schools where there were no 12th grade test takers
LAUSD_act2019 = LAUSD_act2019.drop(LAUSD_act2019[LAUSD_act2019.isna().any(axis=1)].index)

# %%
cols_to_float = ['AvgScrRead','AvgScrEng', 'AvgScrMath', 'AvgScrSci', 'NumGE21', 'PctGE21'] #list of cols to changes dtypes

for column in LAUSD_act2019:
    if column in cols_to_float:
        LAUSD_act2019[column] = pd.to_numeric(LAUSD_act2019[column])  # if the col is in the cols_to_float list change the datatype tp number

LAUSD_act2019.info()

# 200 total rows - 14 rows with 0 Ss who took the test - 1 row that represents district data not school-level data as we want == 185
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 4 to 2294
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CDS         134 non-null    float64
#  1   CCode       134 non-null    float64
#  2   CDCode      134 non-null    float64
#  3   SCode       134 non-null    float64
#  4   RType       134 non-null    object
#  5   SName       134 non-null    object
#  6   DName       134 non-null    object
#  7   CName       134 non-null    object
#  8   Enroll12    134 non-null    float64
#  9   NumTstTakr  134 non-null    float64
#  10  AvgScrRead  134 non-null    int64
#  11  AvgScrEng   134 non-null    int64
#  12  AvgScrMath  134 non-null    int64
#  13  AvgScrSci   134 non-null    int64
#  14  NumGE21     134 non-null    int64
#  15  PctGE21     134 non-null    float64
#  16  Year        134 non-null    object
# dtypes: float64(7), int64(5), object(5)
# memory usage: 18.8+ KB

# %%
LAUSD_act2019.columns
# Out:
# Index(['CDS', 'CCode', 'CDCode', 'SCode', 'RType', 'SName', 'DName', 'CName',
#        'Enroll12', 'NumTstTakr', 'AvgScrRead', 'AvgScrEng', 'AvgScrMath',
#        'AvgScrSci', 'NumGE21', 'PctGE21', 'Year'],
#       dtype='object')

# %%
# rename cols
# Column names should be all lowercase.
# Column names should not contain space
# Column names should be unique and informative.

LAUSD_act2019.columns = [col.lower() for col in LAUSD_act2019.columns]     #list comprehension to rename cols
LAUSD_act2019.head()
# Out:
#              cds  ccode     cdcode      scode rtype  \
# 4   1.964733e+13   19.0  1964733.0  1935121.0     S
# 6   1.964733e+13   19.0  1964733.0   126615.0     S
# 23  1.964733e+13   19.0  1964733.0   118588.0     S
# 29  1.964733e+13   19.0  1964733.0  1933852.0     S
# 34  1.964733e+13   19.0  1964733.0   127217.0     S
#
#                                                 sname                dname  \
# 4                         Abraham Lincoln Senior High  Los Angeles Unified
# 6   Academies of Education and Empowerment at Cars...  Los Angeles Unified
# 23      Alain Leroy Locke College Preparatory Academy  Los Angeles Unified
# 29                     Alexander Hamilton Senior High  Los Angeles Unified
# 34        Alliance Alice M. Baxter College-Ready High  Los Angeles Unified
#
#           cname  enroll12  numtsttakr  avgscrread  avgscreng  avgscrmath  \
# 4   Los Angeles     226.0        19.0          21         20          23
# ...

# %% [markdown]
# #### *Dataset 2 - 2019 CA SAT Data* ####

# %% [markdown]
# ### Data cleaning applied to SAT dataset
# * renamed column names
# * dropped unwanted columns
# * filtered dataset for schools within the Lod Angeles Unified district
# * filtered dataset to only include rows at the school aggregate level
# * addressed nulls/missing values and special character '*'
# * change data types to its appropriate data type

# %%
# import sat_2019_ca csv data and assign it to a df called sat_2019_ca
sat_2019_ca = pd.read_csv('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/data/sat_2019_ca.csv')
sat_2019_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
# rename cols to all lowercase

sat_2019_ca.columns = [col.lower() for col in sat_2019_ca.columns]     #list comprehension
sat_2019_ca.head()
# Out:
#             cds  ccode     cdcode      scode rtype                    sname  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  dname        cname  enroll12  numtsttakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   numerwbenchmark11 pcterwbenchmark11 nummathbenchmark11 pctmathbenchmark11  \
# ...

# %%
sat_2019_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    2579 non-null   float64
#  1   ccode                  2579 non-null   float64
#  2   cdcode                 2579 non-null   float64
#  3   scode                  2579 non-null   float64
#  4   rtype                  2579 non-null   object
#  5   sname                  1982 non-null   object
#  6   dname                  2521 non-null   object
#  7   cname                  2579 non-null   object
#  8   enroll12               2579 non-null   float64
#  9   numtsttakr12           2579 non-null   float64
#  10  numerwbenchmark12      2304 non-null   object
#  11  pcterwbenchmark12      2304 non-null   object
#  12  nummathbenchmark12     2304 non-null   object
#  13  pctmathbenchmark12     2304 non-null   object
# ...

# %%
# drop unwanted cols and use inplace to make the change in the df stick
sat_2019_ca.drop(columns = ['unnamed: 25', 'numerwbenchmark11', 'pcterwbenchmark11', 
                 'nummathbenchmark11','pctmathbenchmark11','totnumbothbenchmark11', 'pctbothbenchmark11', 'enroll11', 'numtsttakr11'], inplace = True)
sat_2019_ca.head(2)
# Out:
#             cds  ccode    cdcode     scode rtype                    sname  \
# 0  6.615981e+12    6.0  661598.0  630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0  661606.0  634758.0     S          Maxwell Sr High
#
#              dname   cname  enroll12  numtsttakr12 numerwbenchmark12  \
# 0   Colusa Unified  Colusa      18.0           0.0               NaN
# 1  Maxwell Unified  Colusa      29.0          10.0                 *
#
#   pcterwbenchmark12 nummathbenchmark12 pctmathbenchmark12  \
# 0               NaN                NaN                NaN
# 1                 *                  *                  *
#
#   totnumbothbenchmark12 pctbothbenchmark12     year
# 0                   NaN                NaN  2018-19
# 1                     *                  *  2018-19

# %%
# filter for LAUSD only & where the school name is not empty

LAUSD_sat2019 = sat_2019_ca[(sat_2019_ca['dname'] == 'Los Angeles Unified')]

# %%
# remove the district data row b/c that's a cumulative of all the schools in LAUSD - do this by filtering rtype = 'D'
LAUSD_sat2019 = LAUSD_sat2019[LAUSD_sat2019['rtype'] != 'D']

# %%
#checking for nulls
LAUSD_sat2019.isna().sum()

# there are 19 schools with NaN for 12th grade data
# Out:
# cds                       0
# ccode                     0
# cdcode                    0
# scode                     0
# rtype                     0
# sname                     0
# dname                     0
# cname                     0
# enroll12                  0
# numtsttakr12              0
# numerwbenchmark12        19
# pcterwbenchmark12        19
# nummathbenchmark12       19
# pctmathbenchmark12       19
# totnumbothbenchmark12    19
# pctbothbenchmark12       19
# year                      0
# dtype: int64

# %%
LAUSD_sat2019 = LAUSD_sat2019.replace('*', np.nan)
# replace * with NaN

# %%
# just double-checking null vals and where they are in the dataset
LAUSD_sat2019[LAUSD_sat2019['numerwbenchmark12'].isnull()]
# Out:
#                cds  ccode     cdcode      scode rtype  \
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# 14    1.964733e+13   19.0  1964733.0  1930387.0     S
# 100   1.964733e+13   19.0  1964733.0   129536.0     S
# 137   1.964733e+13   19.0  1964733.0  1930429.0     S
# 141   1.964734e+13   19.0  1964733.0  6069157.0     S
# ...            ...    ...        ...        ...   ...
# 1808  1.964733e+13   19.0  1964733.0  1930973.0     S
# 1809  1.964733e+13   19.0  1964733.0  1931690.0     S
# 1956  1.964733e+13   19.0  1964733.0  1930064.0     S
# 1957  1.964733e+13   19.0  1964733.0  1930296.0     S
# 1958  1.964733e+13   19.0  1964733.0  1930577.0     S
#
#                                       sname                dname        cname  \
# 4                      Whitman Continuation  Los Angeles Unified  Los Angeles
# 14                             Central High  Los Angeles Unified  Los Angeles
# 100                 Boyle Heights STEM High  Los Angeles Unified  Los Angeles
# ...

# %%
# return rows where there are NaNs
# there are 65 schools where no scores were reported for the 12th graders on the SAT 65/226 ~29% of the high schools
LAUSD_sat2019[LAUSD_sat2019.isna().any(axis=1)]
# Out:
#                cds  ccode     cdcode      scode rtype  \
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# 14    1.964733e+13   19.0  1964733.0  1930387.0     S
# 100   1.964733e+13   19.0  1964733.0   129536.0     S
# 137   1.964733e+13   19.0  1964733.0  1930429.0     S
# 141   1.964734e+13   19.0  1964733.0  6069157.0     S
# ...            ...    ...        ...        ...   ...
# 1808  1.964733e+13   19.0  1964733.0  1930973.0     S
# 1809  1.964733e+13   19.0  1964733.0  1931690.0     S
# 1956  1.964733e+13   19.0  1964733.0  1930064.0     S
# 1957  1.964733e+13   19.0  1964733.0  1930296.0     S
# 1958  1.964733e+13   19.0  1964733.0  1930577.0     S
#
#                                       sname                dname        cname  \
# 4                      Whitman Continuation  Los Angeles Unified  Los Angeles
# 14                             Central High  Los Angeles Unified  Los Angeles
# 100                 Boyle Heights STEM High  Los Angeles Unified  Los Angeles
# ...

# %%
# drop 19 schools where there were no 12th grade test takers
LAUSD_sat2019.drop(LAUSD_sat2019[LAUSD_sat2019['numtsttakr12'] == 0].index)
# Out:
#                cds  ccode     cdcode      scode rtype  \
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# 5     1.964734e+13   19.0  1964733.0  6061451.0     S
# 9     1.964733e+13   19.0  1964733.0   119685.0     S
# ...            ...    ...        ...        ...   ...
# 1924  1.964733e+13   19.0  1964733.0  1995448.0     S
# 1936  1.964733e+13   19.0  1964733.0   125989.0     S
# 1937  1.964733e+13   19.0  1964733.0   126573.0     S
# 1958  1.964733e+13   19.0  1964733.0  1930577.0     S
# 1975  1.964733e+13   19.0  1964733.0   116509.0     S
#
#                                                   sname                dname  \
# 2                                   Belmont Senior High  Los Angeles Unified
# 3                               Canoga Park Senior High  Los Angeles Unified
# 4                                  Whitman Continuation  Los Angeles Unified
# ...

# %%
# drop rows with NaN vals
LAUSD_sat2019.dropna(axis = 'rows', inplace=True)

# %%
#update data types

cols_tofloat = ['numerwbenchmark12', 'pcterwbenchmark12','nummathbenchmark12', 'pctmathbenchmark12', 'totnumbothbenchmark12', 'pctbothbenchmark12']

for column in LAUSD_sat2019:
    if column in cols_tofloat:
        LAUSD_sat2019[column] = pd.to_numeric(LAUSD_sat2019[column])

#LAUSD_sat2019.info()

# %% [markdown]
# #### *Dataset 3 - Free & Reduced Lunch Data* ####

# %% [markdown]
# ### Data cleaning applied to frpm dataset
# * dropped unwanted columns
# * filtered dataset for schools within the Los Angeles Unified district
# * filtered dataset to only include rows at the school aggregate level
# * addressed nulls/missing values
# * renamed column names
# * change data types to its appropriate data type
# * select columns that I want to merge with the ACT/SAT datsets

# %%
# import frpm1819.xlsx data and assign it to a df called frpm1819
# import 2nd tab only
frpm1819 = pd.read_excel('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/data/frpm1819.xlsx', sheet_name = 1, skiprows = [0])
frpm1819.head()
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2018-2019            1          10017       112607     Alameda
# 1     2018-2019            1          10017       123968     Alameda
# 2     2018-2019            1          10017       124172     Alameda
# 3     2018-2019            1          10017       125567     Alameda
# 4     2018-2019            1          10017       130401     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0   Envision Academy for Arts & Technology  County Office of Education (COE)
# 1  Community School for Creative Education  County Office of Education (COE)
# 2                          Yu Ming Charter  County Office of Education (COE)
# ...

# %%
frpm1819.columns

# columns to keep:
#['Academic Year', 'County Code', 'District Code', 'School Code', 'County Name', 'District Name', 'School Name', 
# 'District Type', 'School Type', 'Educational \nOption Type', 'Charter \nSchool \n(Y/N)', 
#'Charter \nSchool \nNumber','Charter \nFunding \nType'
# 'Enrollment \n(K-12), 'Percent (%) \nEligible Free \n(K-12)'
# 'Percent (%) \nEligible FRPM \n(K-12)'
# Out:
# Index(['Academic Year', 'County Code', 'District Code', 'School Code',
#        'County Name', 'District Name', 'School Name', 'District Type',
#        'School Type', 'Educational \nOption Type', 'NSLP \nProvision \nStatus',
#        'Charter \nSchool \n(Y/N)', 'Charter \nSchool \nNumber',
#        'Charter \nFunding \nType', 'IRC', 'Low Grade', 'High Grade',
#        'Enrollment \n(K-12)', 'Free Meal \nCount \n(K-12)',
#        'Percent (%) \nEligible Free \n(K-12)', 'FRPM Count \n(K-12)',
#        'Percent (%) \nEligible FRPM \n(K-12)', 'Enrollment \n(Ages 5-17)',
#        'Free Meal \nCount \n(Ages 5-17)',
#        'Percent (%) \nEligible Free \n(Ages 5-17)', 'FRPM Count \n(Ages 5-17)',
#        'Percent (%) \nEligible FRPM \n(Ages 5-17)',
#        'CALPADS Fall 1 \nCertification Status'],
#       dtype='object')

# %%
# drop columns I don't need
frpm1819.drop(columns = ['NSLP \nProvision \nStatus', 'IRC','Low Grade', 'High Grade','Enrollment \n(Ages 5-17)', 'Free Meal \nCount \n(Ages 5-17)','Percent (%) \nEligible Free \n(Ages 5-17)', 'FRPM Count \n(Ages 5-17)','Percent (%) \nEligible FRPM \n(Ages 5-17)','CALPADS Fall 1 \nCertification Status'], inplace = True)

# %%
frpm1819.head(2)
# Out:
#   Academic Year  County Code  District Code  School Code County Name  \
# 0     2018-2019            1          10017       112607     Alameda
# 1     2018-2019            1          10017       123968     Alameda
#
#                         District Name  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
#
#                                School Name                     District Type  \
# 0   Envision Academy for Arts & Technology  County Office of Education (COE)
# 1  Community School for Creative Education  County Office of Education (COE)
#
#                    School Type Educational \nOption Type  \
# 0        High Schools (Public)               Traditional
# 1  Elementary Schools (Public)               Traditional
#
#   Charter \nSchool \n(Y/N) Charter \nSchool \nNumber Charter \nFunding \nType  \
# 0                      Yes                      0811          Directly funded
# ...

# %%
frpm1819[frpm1819['County Code'] == 19]['District Name'].unique()  #just checking to see what the unique vals are for districts within county 19 to make sure LAUSD isn't spelled differently
# Out:
# array(['Los Angeles County Office of Education', 'ABC Unified',
#        'Antelope Valley Union High', 'Arcadia Unified', 'Azusa Unified',
#        'Baldwin Park Unified', 'Bassett Unified', 'Bellflower Unified',
#        'Beverly Hills Unified', 'Bonita Unified', 'Burbank Unified',
#        'Castaic Union', 'Centinela Valley Union High',
#        'Charter Oak Unified', 'Claremont Unified',
#        'Covina-Valley Unified', 'Culver City Unified', 'Downey Unified',
#        'Duarte Unified', 'Eastside Union Elementary',
#        'East Whittier City Elementary', 'El Monte City',
#        'El Monte Union High', 'El Rancho Unified', 'El Segundo Unified',
#        'Garvey Elementary', 'Glendale Unified', 'Glendora Unified',
#        'Gorman Joint', 'Hawthorne', 'Hermosa Beach City Elementary',
#        'Hughes-Elizabeth Lakes Union Elementary', 'Inglewood Unified',
#        'Keppel Union Elementary', 'La Canada Unified',
#        'Lancaster Elementary', 'Las Virgenes Unified',
# ...

# %%
#filter dataset for only LAUSD schools
LAUSD_frpm1819 = frpm1819[frpm1819['District Name'] == 'Los Angeles Unified']

# %%
LAUSD_frpm1819[LAUSD_frpm1819['School Type'].isnull()]

# kept this row in b/c it's most likely a category for schools not traditional public or charter
# since I'm going to merge this dataset with the others, I'll leave it as is
# Out:
#      Academic Year  County Code  District Code  School Code  County Name  \
# 2540     2018-2019           19          64733            1  Los Angeles
#
#             District Name                      School Name  \
# 2540  Los Angeles Unified  Nonpublic, Nonsectarian Schools
#
#                 District Type School Type Educational \nOption Type  \
# 2540  Unified School District         NaN                       NaN
#
#      Charter \nSchool \n(Y/N) Charter \nSchool \nNumber  \
# 2540                      NaN                       NaN
#
#      Charter \nFunding \nType  Enrollment \n(K-12)  \
# 2540                      NaN                 2413
#
#       Free Meal \nCount \n(K-12)  Percent (%) \nEligible Free \n(K-12)  \
# 2540                         531                              0.220058
#
#       FRPM Count \n(K-12)  Percent (%) \nEligible FRPM \n(K-12)
# 2540                  531                              0.220058

# %%
# checking for nulls
LAUSD_frpm1819.isnull().sum()
# Out:
# Academic Year                             0
# County Code                               0
# District Code                             0
# School Code                               0
# County Name                               0
# District Name                             0
# School Name                               0
# District Type                             0
# School Type                               1
# Educational \nOption Type                 1
# Charter \nSchool \n(Y/N)                  1
# Charter \nSchool \nNumber               734
# Charter \nFunding \nType                734
# Enrollment \n(K-12)                       0
# Free Meal \nCount \n(K-12)                0
# Percent (%) \nEligible Free \n(K-12)      0
# FRPM Count \n(K-12)                       0
# Percent (%) \nEligible FRPM \n(K-12)      0
# dtype: int64

# %%
LAUSD_frpm1819[LAUSD_frpm1819['Charter \nSchool \n(Y/N)'] == 'No ']
# ran it for == 'No' and only 2 showed up,but more showed up for 'No ' This means some 'No' have spaces 'No '

#replace charter school Y/N 'No ' to 'No'
LAUSD_frpm1819['Charter \nSchool \n(Y/N)'].replace('No ', 'No', inplace =True)
# Out:
# /Users/debbiesim/opt/anaconda3/envs/dsi/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
LAUSD_frpm1819[LAUSD_frpm1819['Charter \nSchool \n(Y/N)'] == 'No']
#count of rows makes sense now 733 Nos - the 1 extra Null is the one row with schooltype null named above
# Out:
#      Academic Year  County Code  District Code  School Code  County Name  \
# 2549     2018-2019           19          64733       101329  Los Angeles
# 2551     2018-2019           19          64733       101618  Los Angeles
# 2555     2018-2019           19          64733       102137  Los Angeles
# 2563     2018-2019           19          64733       102764  Los Angeles
# 2564     2018-2019           19          64733       102913  Los Angeles
# ...            ...          ...            ...          ...          ...
# 3538     2018-2019           19          64733      6118186  Los Angeles
# 3540     2018-2019           19          64733      6119093  Los Angeles
# 3545     2018-2019           19          64733      6120679  Los Angeles
# 3546     2018-2019           19          64733      6120794  Los Angeles
# 3547     2018-2019           19          64733      6120810  Los Angeles
#
#             District Name                                        School Name  \
# ...

# %%
LAUSD_frpm1819[LAUSD_frpm1819['Charter \nSchool \n(Y/N)'] == 'Yes']
# Out:
#      Academic Year  County Code  District Code  School Code  County Name  \
# 2541     2018-2019           19          64733       100289  Los Angeles
# 2542     2018-2019           19          64733       100669  Los Angeles
# 2543     2018-2019           19          64733       100677  Los Angeles
# 2544     2018-2019           19          64733       100743  Los Angeles
# 2545     2018-2019           19          64733       100750  Los Angeles
# ...            ...          ...            ...          ...          ...
# 3541     2018-2019           19          64733      6119531  Los Angeles
# 3542     2018-2019           19          64733      6119903  Los Angeles
# 3543     2018-2019           19          64733      6120471  Los Angeles
# 3544     2018-2019           19          64733      6120489  Los Angeles
# 3548     2018-2019           19          64733      6121081  Los Angeles
#
#             District Name                                 School Name  \
# ...

# %%
# checking to make sure we don't have the same issue with 'Yes ' and 'Yes'
LAUSD_frpm1819['Charter \nSchool \n(Y/N)'].unique()
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %%
LAUSD_frpm1819.head(2)
# Out:
#      Academic Year  County Code  District Code  School Code  County Name  \
# 2540     2018-2019           19          64733            1  Los Angeles
# 2541     2018-2019           19          64733       100289  Los Angeles
#
#             District Name                         School Name  \
# 2540  Los Angeles Unified     Nonpublic, Nonsectarian Schools
# 2541  Los Angeles Unified  N.E.W. Academy of Science and Arts
#
#                 District Type                  School Type  \
# 2540  Unified School District                          NaN
# 2541  Unified School District  Elementary Schools (Public)
#
#      Educational \nOption Type Charter \nSchool \n(Y/N)  \
# 2540                       NaN                      NaN
# 2541               Traditional                      Yes
#
#      Charter \nSchool \nNumber Charter \nFunding \nType  Enrollment \n(K-12)  \
# 2540                       NaN                      NaN                 2413
# ...

# %%
LAUSD_frpm1819.columns = [col.lower().replace(' \n', '_') for col in LAUSD_frpm1819.columns]     #list comprehension to lowercase then replace all \n with space
    
LAUSD_frpm1819.head(2)
# Out:
#      academic year  county code  district code  school code  county name  \
# 2540     2018-2019           19          64733            1  Los Angeles
# 2541     2018-2019           19          64733       100289  Los Angeles
#
#             district name                         school name  \
# 2540  Los Angeles Unified     Nonpublic, Nonsectarian Schools
# 2541  Los Angeles Unified  N.E.W. Academy of Science and Arts
#
#                 district type                  school type  \
# 2540  Unified School District                          NaN
# 2541  Unified School District  Elementary Schools (Public)
#
#      educational_option type charter_school_(y/n) charter_school_number  \
# 2540                     NaN                  NaN                   NaN
# 2541             Traditional                  Yes                  0521
#
#      charter_funding_type  enrollment_(k-12)  free meal_count_(k-12)  \
# 2540                  NaN               2413                     531
# ...

# %%
LAUSD_frpm1819.dtypes   #checking dtypes
#school code is int where it's a float for act/sat data
# Out:
# academic year                        object
# county code                           int64
# district code                         int64
# school code                           int64
# county name                          object
# district name                        object
# school name                          object
# district type                        object
# school type                          object
# educational_option type              object
# charter_school_(y/n)                 object
# charter_school_number                object
# charter_funding_type                 object
# enrollment_(k-12)                     int64
# free meal_count_(k-12)                int64
# percent (%)_eligible free_(k-12)    float64
# frpm count_(k-12)                     int64
# percent (%)_eligible frpm_(k-12)    float64
# dtype: object

# %%
# only pulling the cols I want to merge with the act/sat dfs
LAUSD_frpm1819_final = LAUSD_frpm1819.loc[:,['school code', 'county name', 'district name', 'school name', 'charter_school_(y/n)', 'percent (%)_eligible frpm_(k-12)']]
LAUSD_frpm1819_final.head(2)
# Out:
#       school code  county name        district name  \
# 2540            1  Los Angeles  Los Angeles Unified
# 2541       100289  Los Angeles  Los Angeles Unified
#
#                              school name charter_school_(y/n)  \
# 2540     Nonpublic, Nonsectarian Schools                  NaN
# 2541  N.E.W. Academy of Science and Arts                  Yes
#
#       percent (%)_eligible frpm_(k-12)
# 2540                          0.220058
# 2541                          1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### Merge necessary cols with the ACT & SAT datasets using school code as the key

# %% [markdown]
# #### 1. Merge LAUSD_frpm1819_final data w/ LAUSD_sat2019

# %%
# merge necessary cols with the ACT & SAT datasets using school code?
# left merge b/c we only want to match the values in LAUSD_sat2019 df

LAUSD_sat2019_final = LAUSD_sat2019.merge(LAUSD_frpm1819_final,left_on = LAUSD_sat2019['scode'], right_on = LAUSD_frpm1819['school code'], how = 'left')
LAUSD_sat2019_final.head()
# Out:
#        key_0           cds  ccode     cdcode      scode rtype  \
# 0  1930924.0  1.964733e+13   19.0  1964733.0  1930924.0     S
# 1  1931476.0  1.964733e+13   19.0  1964733.0  1931476.0     S
# 2  6061451.0  1.964734e+13   19.0  1964733.0  6061451.0     S
# 3   119685.0  1.964733e+13   19.0  1964733.0   119685.0     S
# 4  1938885.0  1.964733e+13   19.0  1964733.0  1938885.0     S
#
#                             sname                dname        cname  enroll12  \
# 0             Belmont Senior High  Los Angeles Unified  Los Angeles     206.0
# 1         Canoga Park Senior High  Los Angeles Unified  Los Angeles     227.0
# 2          Foshay Learning Center  Los Angeles Unified  Los Angeles     166.0
# 3     New Open World Academy K-12  Los Angeles Unified  Los Angeles      85.0
# 4  University High School Charter  Los Angeles Unified  Los Angeles     336.0
#
#    ...  pctmathbenchmark12  totnumbothbenchmark12  pctbothbenchmark12  \
# ...

# %%
LAUSD_sat2019_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   key_0                             180 non-null    float64
#  1   cds                               180 non-null    float64
#  2   ccode                             180 non-null    float64
#  3   cdcode                            180 non-null    float64
#  4   scode                             180 non-null    float64
#  5   rtype                             180 non-null    object
#  6   sname                             180 non-null    object
#  7   dname                             180 non-null    object
#  8   cname                             180 non-null    object
#  9   enroll12                          180 non-null    float64
#  10  numtsttakr12                      180 non-null    float64
# ...

# %%
# drop columns I don't need after the merge
LAUSD_sat2019_final.drop(columns = ['key_0', 'county name', 'district name','school code', 'school name'], inplace = True)  # drop columns
LAUSD_sat2019_final.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'totnumbothbenchmark12',
#        'pctbothbenchmark12', 'year', 'charter_school_(y/n)',
#        'percent (%)_eligible frpm_(k-12)'],
#       dtype='object')

# %%
# reorder columns
LAUSD_sat2019_final = LAUSD_sat2019_final[['year', 'cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
                                           'charter_school_(y/n)', 'percent (%)_eligible frpm_(k-12)',
                                           'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
                                           'nummathbenchmark12', 'pctmathbenchmark12', 'totnumbothbenchmark12', 'pctbothbenchmark12']]

# %%
LAUSD_sat2019_final.head(2)
# Out:
#       year           cds  ccode     cdcode      scode rtype  \
# 0  2018-19  1.964733e+13   19.0  1964733.0  1930924.0     S
# 1  2018-19  1.964733e+13   19.0  1964733.0  1931476.0     S
#
#                      sname                dname        cname  \
# 0      Belmont Senior High  Los Angeles Unified  Los Angeles
# 1  Canoga Park Senior High  Los Angeles Unified  Los Angeles
#
#   charter_school_(y/n)  percent (%)_eligible frpm_(k-12)  enroll12  \
# 0                   No                          0.904651     206.0
# 1                   No                          0.886032     227.0
#
#    numtsttakr12  numerwbenchmark12  pcterwbenchmark12  nummathbenchmark12  \
# 0         102.0                 31              30.39                  14
# 1         113.0                 54              47.79                  18
#
#    pctmathbenchmark12  totnumbothbenchmark12  pctbothbenchmark12
# 0               13.73                     14               13.73
# ...

# %% [markdown]
# ### 2. Merge LAUSD_frpm1819_final data w/ LAUSD_act2019

# %%
LAUSD_act2019.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr', 'avgscrread', 'avgscreng', 'avgscrmath',
#        'avgscrsci', 'numge21', 'pctge21', 'year'],
#       dtype='object')

# %%
# left merge b/c we only want to match the values in LAUSD_act2019 df

LAUSD_act2019_final = LAUSD_act2019.merge(LAUSD_frpm1819_final,left_on = LAUSD_act2019['scode'], right_on = LAUSD_frpm1819['school code'], how = 'left')
LAUSD_act2019_final.columns
# Out:
# Index(['key_0', 'cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname',
#        'cname', 'enroll12', 'numtsttakr', 'avgscrread', 'avgscreng',
#        'avgscrmath', 'avgscrsci', 'numge21', 'pctge21', 'year', 'school code',
#        'county name', 'district name', 'school name', 'charter_school_(y/n)',
#        'percent (%)_eligible frpm_(k-12)'],
#       dtype='object')

# %%
# drop columns I don't need after merge
LAUSD_act2019_final.drop(columns = ['key_0', 'county name', 'district name','school code', 'school name'], inplace = True)  # drop columns

#reorder cols
LAUSD_act2019_final = LAUSD_act2019_final[['year','cds', 'ccode', 'cdcode', 'scode', 'rtype', 'dname',
       'cname','sname','charter_school_(y/n)','percent (%)_eligible frpm_(k-12)', 'enroll12', 'numtsttakr', 'avgscrread', 'avgscreng',
       'avgscrmath', 'avgscrsci', 'numge21', 'pctge21']]

LAUSD_act2019_final.columns
# Out:
# Index(['year', 'cds', 'ccode', 'cdcode', 'scode', 'rtype', 'dname', 'cname',
#        'sname', 'charter_school_(y/n)', 'percent (%)_eligible frpm_(k-12)',
#        'enroll12', 'numtsttakr', 'avgscrread', 'avgscreng', 'avgscrmath',
#        'avgscrsci', 'numge21', 'pctge21'],
#       dtype='object')

# %% [markdown]
# ## Export cleaned datasets
#
# I commented out both codes below since the folders/files are already created and will run into an error when I rerun cells

# %%
import pandas as pd
import os   #library to perform system commands within python

# os.mkdir("/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/cleaned_data")  #create a cleaned_data folder within my projects folder

# I commented out this code since the folders/files are already created and don't run into an error when I rerun cells

# %%
# output both df to csv in the folder I created above
# don't create a new index

# LAUSD_act2019_final.to_csv('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/cleaned_data/LAUSD_act2019_final.csv', index = False)
# LAUSD_sat2019_final.to_csv('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/cleaned_data/LAUSD_sat2019_final.csv', index = False)

# %% [markdown]
# ___

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# ### Dataset 1: LAUSD_act2019_final.csv
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |year|object|LAUSD_act2019_final|The academic year corresponding to dataset|
# |cds|float|LAUSD_act2019_final|A unique 14-digit code corresponding to the school within California composed of county code, district code, and school code |
# |ccode|float|LAUSD_act2019_final|A 2-digit code corresponding to county|
# |cdcode|float|LAUSD_act2019_final|A 5-digit code corresponding to school district|
# |scode|float|LAUSD_act2019_final|A 7-digit code corresponding to the school|
# |rtype|object|LAUSD_act2019_final|record type indicates whether the row of data corresponds to school, district, or state (S=School Record D=District/LEA Record X=State Record)|
# |dname|object|LAUSD_act2019_final|district name|
# |cname|object|LAUSD_act2019_final|county name|
# |sname|object|LAUSD_act2019_final|school name|
# |charter_school_(y/n)|object|LAUSD_act2019_final|Indicates whether or not the school identifies as a charter school|
# |percent (%)_eligible frpm_(k-12)|float|LAUSD_act2019_final|The percent of students eligible for free or reduced price meals (FRPM)|
# |enroll12|float|LAUSD_act2019_final|Total count of 12th grade students|
# |numtsttakr|float|LAUSD_act2019_final|Total number of 12th grade students that took the ACT|
# |avgscrread|float|LAUSD_act2019_final|Average ACT reading score for students who took the ACT|
# |avgscreng|float|LAUSD_act2019_final|Average ACT english score for students who took the ACT|
# |avgscrmth|float|LAUSD_act2019_final|Average ACT math score for students who took the ACT|
# |avgscrsci|float|LAUSD_act2019_final|Average ACT science score for students who took the ACT |
# |numge21|float|LAUSD_act2019_final|The number of ACT testtakers that met the ACT benchmark score of 21|
# |pctge21|ifloat|LAUSD_act2019_final|The percent of ACT testtakers that met the ACT benchmark score of 21|
#
# ### Dataset 2: LAUSD_sat2019_final.csv
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |year|object|LAUSD_sat2019_final|The academic year corresponding to dataset|
# |cds|float|LAUSD_sat2019_final|A unique 14-digit code corresponding to the school within California composed of county code, district code, and school code |
# |ccode|float|LAUSD_sat2019_final|A 2-digit code corresponding to county|
# |cdcode|float|LAUSD_sat2019_final|A 5-digit code corresponding to school district|
# |scode|float|LAUSD_sat2019_final|A 7-digit code corresponding to the school|
# |rtype|object|LAUSD_sat2019_final|record type indicates whether the row of data corresponds to school, district, or state (S=School Record D=District/LEA Record X=State Record)|
# |sname|object|LAUSD_sat2019_final|school name|
# |dname|object|LAUSD_sat2019_final|district name|
# |cname|object|LAUSD_sat2019_final|county name|
# |charter_school_(y/n)|object|LAUSD_sat2019_final|Indicates whether or not the school identifies as a charter school|
# |percent (%)_eligible frpm_(k-12)|float|LAUSD_sat2019_final|The percent of students eligible for free or reduced price meals (FRPM)|
# |enroll12|float|LAUSD_sat2019_final|Total count of 12th grade students|
# |numtsttakr12|float|LAUSD_sat2019_final|Total count of 12th grade students that took the SAT|
# |numerwbenchmark12|float|LAUSD_sat2019_final|Total count of 12th grade testtakers that met the reading and writing benchmark|
# |pcterwbenchmark12|float|LAUSD_sat2019_final|Percent of 12th grade testtakers that met the reading and writing benchmark|
# |nummathbenchmark12|float|LAUSD_sat2019_final|Total count of 12th grade testtakers that met the math benchmark|
# |pctmathbenchmark12|float|LAUSD_sat2019_final|Percent of 12th grade testtakers that met the math benchmark|
# |totnumbothbenchmark12|float|LAUSD_sat2019_final|Total count of 12th grade testtakers that met both reading/writing and math benchmark|
# |pctbothbenchmark12|float|LAUSD_sat2019_final|Percent of 12th grade testtakers that met both reading/writing and math benchmark|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any schools show to have >50% participation on *both* tests each year?
#         - Do any schools show to have >50% meet *both* content benchmarks on the SAT?
#         - Which _ have the highest median SAT and ACT scores for admittance?
#         - Which _ have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ---
# Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops.

# %%
# numeric columns only
numeric_cols_ACT = ['percent (%)_eligible frpm_(k-12)', 'enroll12', 'numtsttakr', 'avgscrread', 'avgscreng',
       'avgscrmath', 'avgscrsci', 'numge21', 'pctge21']   # put the numeric columns in the list

# using dict comprehension apply standard dev function I created above to each numeric col
# {std_deviation(col) for col in numeric_cols} # this isn't done b/c there's no key value pair

ACT_std = {col: std_deviation(LAUSD_act2019_final[col]) for col in numeric_cols_ACT}
ACT_std
# Out:
# {'percent (%)_eligible frpm_(k-12)': 0.14555829029585557,
#  'enroll12': 195.3170028997528,
#  'numtsttakr': 49.75182617818322,
#  'avgscrread': 3.1698853784548384,
#  'avgscreng': 3.5240003899050283,
#  'avgscrmath': 2.5676413995868574,
#  'avgscrsci': 2.586701084285367,
#  'numge21': 25.953890304157667,
#  'pctge21': 21.93555618206905}

# %%
# numeric columns only
numeric_cols_SAT = ['percent (%)_eligible frpm_(k-12)', 'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
                'nummathbenchmark12', 'pctmathbenchmark12', 'totnumbothbenchmark12', 'pctbothbenchmark12']   # put the numeric columns in the list

# using dict comprehension apply standard dev function I created above to each numeric col
SAT_std = {col: std_deviation(LAUSD_sat2019_final[col]) for col in numeric_cols_SAT}
SAT_std
# Out:
# {'percent (%)_eligible frpm_(k-12)': 0.13963713879425393,
#  'enroll12': 179.40490611882987,
#  'numtsttakr12': 93.88627133103351,
#  'numerwbenchmark12': 64.50885167513405,
#  'pcterwbenchmark12': 18.478819938790654,
#  'nummathbenchmark12': 47.02790706814281,
#  'pctmathbenchmark12': 16.32979903361933,
#  'totnumbothbenchmark12': 45.08433626597171,
#  'pctbothbenchmark12': 15.915072933492798}

# %% [markdown]
# ---
# #### **Additional data cleaning determined through EDA process ** ####

# %%
# import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns    #seaborn is made to visualize data which is different from matplotlip

# %%
# taking a quick look at the columns again & drops cols I kept but don't need for analysis moving forward
LAUSD_act2019_final.drop(columns = ['ccode','cdcode', 'rtype'], inplace = True)
LAUSD_act2019_final.head(2)
# Out:
#       year           cds      scode                dname        cname  \
# 0  2018-19  1.964733e+13  1935121.0  Los Angeles Unified  Los Angeles
# 1  2018-19  1.964733e+13   126615.0  Los Angeles Unified  Los Angeles
#
#                                                sname charter_school_(y/n)  \
# 0                        Abraham Lincoln Senior High                   No
# 1  Academies of Education and Empowerment at Cars...                   No
#
#    percent (%)_eligible frpm_(k-12)  enroll12  numtsttakr  avgscrread  \
# 0                          0.939962     226.0        19.0          21
# 1                          0.703154     126.0        16.0          18
#
#    avgscreng  avgscrmath  avgscrsci  numge21  pctge21
# 0         20          23         22       11    57.89
# 1         18          18         17        5    31.25

# %%
LAUSD_sat2019_final.drop(columns = ['ccode','cdcode', 'rtype'], inplace = True)
LAUSD_sat2019_final.head(2)
# Out:
#       year           cds      scode                    sname  \
# 0  2018-19  1.964733e+13  1930924.0      Belmont Senior High
# 1  2018-19  1.964733e+13  1931476.0  Canoga Park Senior High
#
#                  dname        cname charter_school_(y/n)  \
# 0  Los Angeles Unified  Los Angeles                   No
# 1  Los Angeles Unified  Los Angeles                   No
#
#    percent (%)_eligible frpm_(k-12)  enroll12  numtsttakr12  \
# 0                          0.904651     206.0         102.0
# 1                          0.886032     227.0         113.0
#
#    numerwbenchmark12  pcterwbenchmark12  nummathbenchmark12  \
# 0                 31              30.39                  14
# 1                 54              47.79                  18
#
#    pctmathbenchmark12  totnumbothbenchmark12  pctbothbenchmark12
# 0               13.73                     14               13.73
# 1               15.93                     18               15.93

# %% [markdown]
# **Which schools have the highest and lowest participation rates for 2019 ACT and SAT?
# Does it differ by frpm or if it's a charter school?**

# %%
# add participation rate col for ACT
LAUSD_act2019_final['particrate'] = LAUSD_act2019_final['numtsttakr'] / LAUSD_act2019_final['enroll12']
LAUSD_act2019_final.head(2)
# Out:
#       year           cds      scode                dname        cname  \
# 0  2018-19  1.964733e+13  1935121.0  Los Angeles Unified  Los Angeles
# 1  2018-19  1.964733e+13   126615.0  Los Angeles Unified  Los Angeles
#
#                                                sname charter_school_(y/n)  \
# 0                        Abraham Lincoln Senior High                   No
# 1  Academies of Education and Empowerment at Cars...                   No
#
#    percent (%)_eligible frpm_(k-12)  enroll12  numtsttakr  avgscrread  \
# 0                          0.939962     226.0        19.0          21
# 1                          0.703154     126.0        16.0          18
#
#    avgscreng  avgscrmath  avgscrsci  numge21  pctge21  particrate
# 0         20          23         22       11    57.89    0.084071
# 1         18          18         17        5    31.25    0.126984

# %%
# add participation rate col for 12th grade SAT
LAUSD_sat2019_final['particrate12'] = (LAUSD_sat2019_final['numtsttakr12'] / LAUSD_sat2019_final['enroll12'])
LAUSD_sat2019_final.head(2)
# Out:
#       year           cds      scode                    sname  \
# 0  2018-19  1.964733e+13  1930924.0      Belmont Senior High
# 1  2018-19  1.964733e+13  1931476.0  Canoga Park Senior High
#
#                  dname        cname charter_school_(y/n)  \
# 0  Los Angeles Unified  Los Angeles                   No
# 1  Los Angeles Unified  Los Angeles                   No
#
#    percent (%)_eligible frpm_(k-12)  enroll12  numtsttakr12  \
# 0                          0.904651     206.0         102.0
# 1                          0.886032     227.0         113.0
#
#    numerwbenchmark12  pcterwbenchmark12  nummathbenchmark12  \
# 0                 31              30.39                  14
# 1                 54              47.79                  18
#
#    pctmathbenchmark12  totnumbothbenchmark12  pctbothbenchmark12  particrate12
# 0               13.73                     14               13.73      0.495146
# ...

# %%
# rows and cols
print(LAUSD_act2019_final.shape)
print(LAUSD_sat2019_final.shape)
# Out:
# (134, 17)
# (180, 17)

# %%
LAUSD_act2019_final.describe().T   #transposing for a different view
# Out:
#                                   count          mean           std  \
# cds                               134.0  1.964733e+13  1.251697e+06
# scode                             134.0  9.611907e+05  1.251697e+06
# percent (%)_eligible frpm_(k-12)  134.0  8.269801e-01  1.461045e-01
# enroll12                          134.0  2.356045e+02  1.960499e+02
# numtsttakr                        134.0  6.678358e+01  4.993851e+01
# avgscrread                        134.0  1.869403e+01  3.181780e+00
# avgscreng                         134.0  1.788060e+01  3.537224e+00
# avgscrmath                        134.0  1.852239e+01  2.577276e+00
# avgscrsci                         134.0  1.841791e+01  2.596407e+00
# numge21                           134.0  2.000746e+01  2.605128e+01
# pctge21                           134.0  2.934060e+01  2.201787e+01
# particrate                        134.0           inf           NaN
#
#                                            min           25%           50%  \
# ...

# %%
LAUSD_act2019_final.describe().T
# Out:
#                                   count          mean           std  \
# cds                               134.0  1.964733e+13  1.251697e+06
# scode                             134.0  9.611907e+05  1.251697e+06
# percent (%)_eligible frpm_(k-12)  134.0  8.269801e-01  1.461045e-01
# enroll12                          134.0  2.356045e+02  1.960499e+02
# numtsttakr                        134.0  6.678358e+01  4.993851e+01
# avgscrread                        134.0  1.869403e+01  3.181780e+00
# avgscreng                         134.0  1.788060e+01  3.537224e+00
# avgscrmath                        134.0  1.852239e+01  2.577276e+00
# avgscrsci                         134.0  1.841791e+01  2.596407e+00
# numge21                           134.0  2.000746e+01  2.605128e+01
# pctge21                           134.0  2.934060e+01  2.201787e+01
# particrate                        134.0           inf           NaN
#
#                                            min           25%           50%  \
# ...

# %% [markdown]
# - I noticed that the stats table was returning inf and NaN which means when I created the 'particrate' column some rows had 0 enrollment
# - After exploring the data, it was because one row of data had 0 enrollment, but had ACT data. I did some additional research and found that the school is a 6-8 school and shouldn't have any ACT data

# %%
# removed this row of data
LAUSD_act2019_final = LAUSD_act2019_final[LAUSD_act2019_final['sname'] != 'PUC Nueva Esperanza Charter Academy']

# %%
# SAT data
LAUSD_sat2019_final.describe().T   #transposing for a different view
# Out:
#                                   count          mean           std  \
# cds                               180.0  1.964733e+13  1.331202e+06
# scode                             180.0  9.055406e+05  1.331202e+06
# percent (%)_eligible frpm_(k-12)  180.0  8.428639e-01  1.400266e-01
# enroll12                          180.0  2.097278e+02  1.799053e+02
# numtsttakr12                      180.0  1.097500e+02  9.414816e+01
# numerwbenchmark12                 180.0  5.761667e+01  6.468879e+01
# pcterwbenchmark12                 180.0  4.720406e+01  1.853036e+01
# nummathbenchmark12                180.0  3.306111e+01  4.715909e+01
# pctmathbenchmark12                180.0  2.499672e+01  1.637535e+01
# totnumbothbenchmark12             180.0  3.036111e+01  4.521009e+01
# pctbothbenchmark12                180.0  2.258228e+01  1.595947e+01
# particrate12                      180.0  5.672625e-01  2.096011e-01
#
#                                            min           25%           50%  \
# ...

# %%
# noticed that particrate12 max is greater than 1 which is odd
# only 2 rows, so I'm choosing to leave the data as is. After doing research it could be because enrollment count is based on final count in the Fall versus at time of test
LAUSD_sat2019_final[LAUSD_sat2019_final['particrate12'] > 1]
# Out:
#         year           cds      scode  \
# 145  2018-19  1.964733e+13  1996610.0
# 158  2018-19  1.964733e+13   127795.0
#
#                                                  sname                dname  \
# 145                     Los Angeles Leadership Academy  Los Angeles Unified
# 158  Contreras Learning Center-School of Social Jus...  Los Angeles Unified
#
#            cname charter_school_(y/n)  percent (%)_eligible frpm_(k-12)  \
# 145  Los Angeles                  Yes                          0.841270
# 158  Los Angeles                   No                          0.950108
#
#      enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 145      44.0          46.0                 17              36.96
# 158      90.0          92.0                 20              21.74
#
#      nummathbenchmark12  pctmathbenchmark12  totnumbothbenchmark12  \
# 145                   5               10.87                      5
# ...

# %%
#15 rows - I'm going to replace the vals with 1 - 100%
LAUSD_act2019_final['particrate'] = LAUSD_act2019_final['particrate'].apply(lambda x: 1 if x > 1 else x)

# %%
LAUSD_act2019_final[LAUSD_act2019_final['particrate'] > 1]
# Out:
# Empty DataFrame
# Columns: [year, cds, scode, dname, cname, sname, charter_school_(y/n), percent (%)_eligible frpm_(k-12), enroll12, numtsttakr, avgscrread, avgscreng, avgscrmath, avgscrsci, numge21, pctge21, particrate]
# Index: []

# %%
LAUSD_act2019_final.describe().T
# Out:
#                                   count          mean           std  \
# cds                               133.0  1.964733e+13  1.254346e+06
# scode                             133.0  9.674156e+05  1.254346e+06
# percent (%)_eligible frpm_(k-12)  133.0  8.277374e-01  1.463926e-01
# enroll12                          133.0  2.373759e+02  1.957117e+02
# numtsttakr                        133.0  6.712030e+01  4.997439e+01
# avgscrread                        133.0  1.871429e+01  3.185125e+00
# avgscreng                         133.0  1.790226e+01  3.541667e+00
# avgscrmath                        133.0  1.853383e+01  2.583599e+00
# avgscrsci                         133.0  1.843609e+01  2.597649e+00
# numge21                           133.0  2.015038e+01  2.609699e+01
# pctge21                           133.0  2.952699e+01  2.199473e+01
# particrate                        133.0  3.921836e-01  3.117090e-01
#
#                                            min           25%           50%  \
# ...

# %%
print('ACT: ', LAUSD_act2019_final.columns)
print('SAT: ', LAUSD_sat2019_final.columns)
# Out:
# ACT:  Index(['year', 'cds', 'scode', 'dname', 'cname', 'sname',
#        'charter_school_(y/n)', 'percent (%)_eligible frpm_(k-12)', 'enroll12',
#        'numtsttakr', 'avgscrread', 'avgscreng', 'avgscrmath', 'avgscrsci',
#        'numge21', 'pctge21', 'particrate'],
#       dtype='object')
# SAT:  Index(['year', 'cds', 'scode', 'sname', 'dname', 'cname',
#        'charter_school_(y/n)', 'percent (%)_eligible frpm_(k-12)', 'enroll12',
#        'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'totnumbothbenchmark12',
#        'pctbothbenchmark12', 'particrate12'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **Exploratory Data Analysis Questions**
# - Which schools have the highest and lowest participation rates for 2019 ACT and SAT? does it differ by frpm or if it's a charter school?
# - How are schools performing on math versus reading/writing?
# - What does the distribution of performance look like?
# - Which LAUSD school has the highest and lowest mean test scores in comparison?

# %%
LAUSD_act2019_final.describe().T
# Out:
#                                   count          mean           std  \
# cds                               133.0  1.964733e+13  1.254346e+06
# scode                             133.0  9.674156e+05  1.254346e+06
# percent (%)_eligible frpm_(k-12)  133.0  8.277374e-01  1.463926e-01
# enroll12                          133.0  2.373759e+02  1.957117e+02
# numtsttakr                        133.0  6.712030e+01  4.997439e+01
# avgscrread                        133.0  1.871429e+01  3.185125e+00
# avgscreng                         133.0  1.790226e+01  3.541667e+00
# avgscrmath                        133.0  1.853383e+01  2.583599e+00
# avgscrsci                         133.0  1.843609e+01  2.597649e+00
# numge21                           133.0  2.015038e+01  2.609699e+01
# pctge21                           133.0  2.952699e+01  2.199473e+01
# particrate                        133.0  3.921836e-01  3.117090e-01
#
#                                            min           25%           50%  \
# ...

# %%
LAUSD_sat2019_final.describe().T
# Out:
#                                   count          mean           std  \
# cds                               180.0  1.964733e+13  1.331202e+06
# scode                             180.0  9.055406e+05  1.331202e+06
# percent (%)_eligible frpm_(k-12)  180.0  8.428639e-01  1.400266e-01
# enroll12                          180.0  2.097278e+02  1.799053e+02
# numtsttakr12                      180.0  1.097500e+02  9.414816e+01
# numerwbenchmark12                 180.0  5.761667e+01  6.468879e+01
# pcterwbenchmark12                 180.0  4.720406e+01  1.853036e+01
# nummathbenchmark12                180.0  3.306111e+01  4.715909e+01
# pctmathbenchmark12                180.0  2.499672e+01  1.637535e+01
# totnumbothbenchmark12             180.0  3.036111e+01  4.521009e+01
# pctbothbenchmark12                180.0  2.258228e+01  1.595947e+01
# particrate12                      180.0  5.672625e-01  2.096011e-01
#
#                                            min           25%           50%  \
# ...

# %% [markdown]
# ### At a glance:
# - 29.5% of students met the ACT benchmark and 22.6% met the SAT benchmark
# - At first glance, there's a pretty big gap in the % of testtakers that met the math benchmark (25.0%) vs reading/writing (47.2%) on the SAT
# - The median participation rate on the SAT is 55.4% and ACT is 28.2%

# %% [markdown]
# ### What does participation rate and % frpm look like for the top performing/lowest performing 5% of schools on the ACT/SAT?
#
# - There's slightly higher participation rate in the ACT at the lowest performing 5% of schools, all, but 6 of the schools are > 90% frpm lunch
# - The top 5% performing schools seem to have lower/similar participation rate

# %%
LAUSD_act2019_final.sort_values(by = 'pctge21', ascending = False)[:7]    # take the df, sort it descending - show 7 schools
# Out:
#         year           cds      scode                dname        cname  \
# 81   2018-19  1.964733e+13  1932847.0  Los Angeles Unified  Los Angeles
# 93   2018-19  1.964733e+13  1995836.0  Los Angeles Unified  Los Angeles
# 57   2018-19  1.964733e+13  1932623.0  Los Angeles Unified  Los Angeles
# 129  2018-19  1.964733e+13  1938968.0  Los Angeles Unified  Los Angeles
# 64   2018-19  1.964733e+13  1931864.0  Los Angeles Unified  Los Angeles
# 50   2018-19  1.964733e+13   102921.0  Los Angeles Unified  Los Angeles
# 63   2018-19  1.964733e+13  1933746.0  Los Angeles Unified  Los Angeles
#
#                                                  sname charter_school_(y/n)  \
# 81             Los Angeles Center for Enriched Studies                   No
# 93                              Palisades Charter High                  Yes
# 57                         El Camino Real Charter High                  Yes
# 129                               Van Nuys Senior High                   No
# ...

# %%
LAUSD_act2019_final.sort_values(by = 'pctge21')[:7]    # take the df, sort it descending - show 7 schools
# Out:
#         year           cds      scode                dname        cname  \
# 24   2018-19  1.964733e+13   117077.0  Los Angeles Unified  Los Angeles
# 27   2018-19  1.964733e+13   126490.0  Los Angeles Unified  Los Angeles
# 90   2018-19  1.964733e+13   120071.0  Los Angeles Unified  Los Angeles
# 121  2018-19  1.964733e+13  1934371.0  Los Angeles Unified  Los Angeles
# 104  2018-19  1.964733e+13   124529.0  Los Angeles Unified  Los Angeles
# 15   2018-19  1.964733e+13   117598.0  Los Angeles Unified  Los Angeles
# 34   2018-19  1.964733e+13   127910.0  Los Angeles Unified  Los Angeles
#
#                                                  sname charter_school_(y/n)  \
# 24                                        APEX Academy                  Yes
# 27   Augustus F. Hawkins High B Community Health Ad...                   No
# 90                    New Designs Charter School-Watts                  Yes
# 121                       Thomas Jefferson Senior High                   No
# ...

# %% [markdown]
# Seeing similar trends with SAT data as well.
# - gap between % meeting math and ELA benchmark seems larger with the lower performing schools
# - participation rates seem similar, but % eligible frpm is much higher with lower performing schools
# - surprised but top perfoming schools on ACT and SAT have some overlap

# %%
# Taking a look at SAT in the same way
LAUSD_sat2019_final.sort_values(by = 'pctbothbenchmark12', ascending = False)[:5]    # take the df, sort it descending - show 5 schools
# Out:
#         year           cds      scode  \
# 159  2018-19  1.964733e+13  1933746.0
# 68   2018-19  1.964733e+13  1932847.0
# 78   2018-19  1.964733e+13  1995836.0
# 32   2018-19  1.964733e+13   100677.0
# 33   2018-19  1.964733e+13  1932623.0
#
#                                        sname                dname  \
# 159               Granada Hills Charter High  Los Angeles Unified
# 68   Los Angeles Center for Enriched Studies  Los Angeles Unified
# 78                    Palisades Charter High  Los Angeles Unified
# 32                              High Tech LA  Los Angeles Unified
# 33               El Camino Real Charter High  Los Angeles Unified
#
#            cname charter_school_(y/n)  percent (%)_eligible frpm_(k-12)  \
# 159  Los Angeles                  Yes                          0.522989
# 68   Los Angeles                   No                          0.539521
# 78   Los Angeles                  Yes                          0.321862
# ...

# %%
LAUSD_sat2019_final.sort_values(by = 'pctbothbenchmark12')[:5]
# Out:
#        year           cds      scode  \
# 17  2018-19  1.964733e+13   119651.0
# 31  2018-19  1.964733e+13   126490.0
# 96  2018-19  1.964733e+13  1932128.0
# 49  2018-19  1.964733e+13   117077.0
# 6   2018-19  1.964733e+13   122341.0
#
#                                                 sname                dname  \
# 17                                    Sun Valley High  Los Angeles Unified
# 31  Augustus F. Hawkins High B Community Health Ad...  Los Angeles Unified
# 96  Crenshaw Science, Technology, Engineering, Mat...  Los Angeles Unified
# 49                                       APEX Academy  Los Angeles Unified
# 6       Esteban Torres East LA Performing Arts Magnet  Los Angeles Unified
#
#           cname charter_school_(y/n)  percent (%)_eligible frpm_(k-12)  \
# 17  Los Angeles                   No                          0.906005
# 31  Los Angeles                   No                          0.913793
# ...

# %% [markdown]
# ### What percent of students met the ACT and SAT benchmarks? Does it differ whether or not the school is a charter school?
# - There's not a huge difference in whether or not the school identifies as a public charter or traditional public schools when it comes to average % of students meeting benchmarks

# %%
LAUSD_act2019_final.groupby(['charter_school_(y/n)'])[['pctge21']].mean()
# There's not a huge difference in whether or not public charter or traditional public schools
# Out:
#                         pctge21
# charter_school_(y/n)
# No                    30.555132
# Yes                   28.156140

# %%
LAUSD_sat2019_final.groupby(['charter_school_(y/n)'])[['pctbothbenchmark12', 'pctmathbenchmark12', 'pcterwbenchmark12']].mean()
# Out:
#                       pctbothbenchmark12  pctmathbenchmark12  \
# charter_school_(y/n)
# No                             21.333514           23.632973
# Yes                            24.591159           27.190580
#
#                       pcterwbenchmark12
# charter_school_(y/n)
# No                            46.995225
# Yes                           47.540000

# %%
plt.figure(figsize = (5,5))
sns.boxplot(data=LAUSD_act2019_final, x='charter_school_(y/n)', y='pctge21'); # plotting a boxplot for ACT performance based on school type

# nothing here that stands as out to discuss, was originally wondering if public charter vs traditional public school was correllated with perf

# %% [markdown]
# #### Creating a new df that has % of students meeting benchmarks on the SAT and ACT combined to see them side by side

# %%
benchmarkdf_act = LAUSD_act2019_final[['pctge21']].mean()      # calculating the mean of average of select cols
benchmarkdf_act.to_frame()
# Out:
#                  0
# pctge21  29.526992

# %%
benchmarkdf_sat = LAUSD_sat2019_final[['pctbothbenchmark12', 'pctmathbenchmark12', 'pcterwbenchmark12']].mean()      # calculating the mean of average of select cols
benchmarkdf_sat.to_frame()
# Out:
#                             0
# pctbothbenchmark12  22.582278
# pctmathbenchmark12  24.996722
# pcterwbenchmark12   47.204056

# %%
benchmarkdf = pd.concat([benchmarkdf_sat, benchmarkdf_act]).to_frame() # wanted to merge the means into one df for later
benchmarkdf.reset_index(inplace=True)                                  # reset the index
benchmarkdf
# Out:
#                 index          0
# 0  pctbothbenchmark12  22.582278
# 1  pctmathbenchmark12  24.996722
# 2   pcterwbenchmark12  47.204056
# 3             pctge21  29.526992

# %% [markdown]
# ### Looking at the distribution of % of students meeting the math vs reading benchmark on the SAT

# %%
sns.histplot(data=LAUSD_sat2019_final, x='pctmathbenchmark12', bins = 15 );  # create a histogram of the % of students meeting math benchmarks
# this histogram is skewed right with most school having a lower % of students meeting math benchmarks

# %%
sns.histplot(data=LAUSD_sat2019_final, x='pcterwbenchmark12', bins = 15 );  # create a histogram of the % of students meeting reading/writing benchmarks
# this histogram is not perfect, but it has a more normal distribution except for the ~10 schools where 85-90% of testtakers are meeting benchmarks

# %%
# std deviation of the % of students meeting the math benchmark on the SAT
# std deviation of the % of students meeting the reading/writing benchmark on the SAT

print(LAUSD_sat2019_final['pcterwbenchmark12'].std())
print(LAUSD_sat2019_final['pctmathbenchmark12'].std())
print(LAUSD_sat2019_final['pctbothbenchmark12'].std())
print(LAUSD_act2019_final['pctge21'].std())

# the std tells me that performance is pretty spread out whether you are looking at the ACT or SA
# Out:
# 18.53036486440754
# 16.37534946807969
# 15.95946652860664
# 21.994730980084903

# %%
plt.figure(figsize = (5,5))

sns.boxplot(data=LAUSD_sat2019_final[['pctmathbenchmark12', 'pcterwbenchmark12', 'pctbothbenchmark12']], orient='h');
# boxplot to see the distribution of SAT averages split up by content and composite
# continuing to see that the reading/writing performance is stronger
# there are outliers with math performance which connects to the histogram we looked at above

# %%
# create an heatmap to just see correlation between numerical variables for ACT data
plt.figure(figsize=(10,10))   #plot figure size
sns.heatmap(LAUSD_act2019_final[['percent (%)_eligible frpm_(k-12)', 'enroll12', 'numtsttakr',
       'avgscrread', 'avgscreng', 'avgscrmath', 'avgscrsci', 'numge21',
       'pctge21', 'particrate']].corr(),
           cmap='coolwarm',
           annot=True,
           fmt='.2f');


# only looking at features on the same scale, the strongest correlation is between % frpm an % of students meeting the 21 benchmark score
# There's a -0.68 correlation

# %% [markdown]
# ### Creating a box plot of the composite SAT/SAT averages to see if anything shows up

# %%
df1 = LAUSD_sat2019_final['pctbothbenchmark12']  # assigning series from datasets to a new df
df2 = LAUSD_act2019_final['pctge21']

# %%
df1 = pd.DataFrame(df1)  # convert series to data frames
df2 = pd.DataFrame(df2)
df1['assessment'] = 'sat2019'  #adding a column of constant strings
df2['assessment'] = 'act2019'
df1.rename(columns = {'pctbothbenchmark12': '% Met Benchmark'}, inplace=True)   #renaming the column names
df2.rename(columns = {'pctge21': '% Met Benchmark'}, inplace=True)

# %%
benchmark_met = pd.concat([df1,df2])  #concating the dfs
benchmark_met
# Out:
#      % Met Benchmark assessment
# 0              13.73    sat2019
# 1              15.93    sat2019
# 2              33.96    sat2019
# 3               8.82    sat2019
# 4              39.38    sat2019
# ..               ...        ...
# 129            82.47    act2019
# 130            20.00    act2019
# 131            59.38    act2019
# 132            17.14    act2019
# 133            16.18    act2019
#
# [313 rows x 2 columns]

# %%
plt.figure(figsize = (5,5))
sns.boxplot(data=benchmark_met, x='assessment', y='% Met Benchmark');  #using the above df to create box plots

# takeaway here is that % of students meeting act benchmarks in LAUSD has a larger range
# is the SAT more difficult than the act?

# %% [markdown]
# ---

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*
#
# - performance on math is stronger than reading/writing on the ACT
# - school type (charter vs traditional public) does not seem to have any obvious relationship to ACT/SAT performance
# - student participation on the ACT/SAT is lower across the district and doesn't seem to have any correlation to performance within LAUSD

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# * Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# scatter math(x) vs reading writing (y) - anything above the line it means y val is larger than x
# line from 00-100,100
# on the line means the school has same perf on math and ELA

plt.figure(figsize=(10,6))
sns.scatterplot(data=LAUSD_sat2019_final, x='pctmathbenchmark12',y='pcterwbenchmark12', palette='viridis')
plt.plot([0, 100], [0,100], linewidth=1, color='orange' )  # created a line to represent equal performance on the math and reading writing
plt.title('2019 12th Grade SAT Performance: Math vs Reading/Writing ', fontsize=14)
plt.xlabel('% of Testtakers Met SAT Math Benchmark', fontsize=10)
plt.ylabel('% of Testtakers Met Reading/Writing Benchmark', fontsize=10)
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/sat_erw_math_benchmarks.png');

# you can see here that there are a couple of schools where the student performed equally well on math and reading,
# but for the rest, they performed better on reading/writing than math

# %%
diff = LAUSD_sat2019_final['pcterwbenchmark12'] - LAUSD_sat2019_final['pctmathbenchmark12']

plt.figure(figsize=(8,8))
sns.histplot(diff, bins=10, color='coral')
plt.title('Difference in 12th Grade SAT Math & Reading/Writing Performance in 2019', fontsize=14)
plt.xlabel('Difference in % Met Benchmark - Reading/Writing & Math', fontsize=11)
plt.ylabel('Count of Schools', fontsize=11)
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/hist-sat_erw_math_benchmarks.png');

# when you look at the distribution of the difference in scores between reading/writing and math,
# you can see that most schools land in the 16-32 point difference range

# %%
# scatter plot
# free and reduced lunch
# y - score (ACT & SAT)

#there's a correlation here between % of free & reduced price lunch and % of students meeting the act benchmark

plt.figure(figsize=(10,6))
sns.scatterplot(data = LAUSD_act2019_final,
                x = 'percent (%)_eligible frpm_(k-12)',
                y = 'pctge21')
plt.title('% Eligible for Free & Reduced Lunch vs % Met ACT Benchmark', fontsize=14)
plt.xlabel('% Eligible for Free & Reduced Lunch', fontsize=11)
plt.ylabel('% Met ACT Benchmark', fontsize=11);
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/frpm_act.png');

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data = LAUSD_sat2019_final,
                x = 'percent (%)_eligible frpm_(k-12)',
                y = 'pctbothbenchmark12',
               color = 'green')
plt.title('% Eligible for Free & Reduced Lunch vs % Met SAT Benchmark', fontsize=14)
plt.xlabel('% Eligible for Free & Reduced Lunch', fontsize=11)
plt.ylabel('% Met Reading/Writing & Math Benchmarks', fontsize=11);
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/frpm_sat.png');

#there's a correlation here between % of free & reduced price lunch and % of students meeting the act benchmark

# %%
plt.figure(figsize = (8,2))
p1 = sns.boxplot(data=LAUSD_sat2019_final[['particrate12']], color='red', orient='h')
p1.set(xlabel=None)
p1.set_title('2019 12th Grade SAT Participation Rate', fontsize= 12, fontweight='bold')
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/partratesat.png');

# %%
plt.figure(figsize = (8,2))
p1 = sns.boxplot(data=LAUSD_act2019_final[['particrate']], color='green', orient='h')
p1.set(xlabel=None)
p1.set_title('2019 12th Grade ACT Participation Rate', fontsize= 12, fontweight='bold')
plt.savefig('/Users/debbiesim/Desktop/GADSI-Course/Projects/Project 1/project_1/plots/partrateact.png');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# 1. External partner should focus coaching mainly on improving math content knowledge. It's evident that students are struggling to meet math ACT/SAT benchmarks.
# 2. % of students eligible for free & reduced lunch is a metric worth considering in narrowing down the list of schools to support through the partnership. This isn't the only metric, but could be looked at in addition to other potential metrics such as % of students that are enrolled in AP courses, school location trends, and % of ELL (As of 2021, 26% of the district identify as ELL ([*source*](https://achieve.lausd.net/cms/lib/CA01000043/Centricity/Domain/1371/22-26_Strategic_Plan.pdf))). These are other metrics the district should explore.
# 3. ACT/SAT may no longer be the best assessment to measure college & career readiness. District could utilize middle school results from the Smarter Balanced state assessments.
#     * As of 2022, ACT/SAT no longer administered by the CA Department of Education ([*source*](https://www.cde.ca.gov/re/pr/satdata.asp)).
#     * Many institutions no longer require ACT/SAT as prerequisites to application ([*source*](https://fairtest.org/test-optional-list/)).
#     * Student performance on formative assessments in middle school or 9th grade may be early indicators of college and career readiness and may aid the district in early intervention as well.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
